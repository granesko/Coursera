# %%
import matplotlib.pyplot as plt
import math
import numpy as np
from scipy import linalg

# %%
x = [i for i in range(16)]
y = [math.sin(x / 5) * math.exp(x / 10) + 5 * math.exp(-x / 2) for x in range(16)]

# %%
plt.plot(x,y, label = 'f(x) = sin(x / 5) * exp(x / 10) + 5 * exp(-x / 2)')
plt.title('График функции', fontsize = 18)
plt.ylabel('Y', fontsize = 15)
plt.xlabel('X', fontsize = 15)
plt.legend(loc = 'best')

# %%
x_arr = [1,15]
y_arr = [(math.sin(x / 5) * math.exp(x / 10) + 5 * math.exp(-x / 2)) for x in range(2)]

# %%
x[15],y[15]
# Out:
# (15, 0.6352214195786656)

# %%
A = np.array([[x[1],y[1]],[x[15],y[15]]])
A
# Out:
# array([[ 1.        ,  3.25221687],
#        [15.        ,  0.63522142]])

# %%
l_x = np.array([[1,1],[15,1]])
r_y = np.array([[A[0,1]],[A[1,1]]])
l_x
# Out:
# array([[ 1,  1],
#        [15,  1]])

# %%
f_coef = linalg.solve(l_x,r_y)

# %%
f_coef
# Out:
# array([[-0.18692825],
#        [ 3.43914511]])

# %%
def func(x):
    y = -0.18692825*x + 3.43914511
    return y

# %%
x_pribl = np.array([i for i in range(15)])
y_pribl = np.array([func(x_pribl) for x_pribl in range(15)])
y_pribl
# Out:
# array([3.43914511, 3.25221686, 3.06528861, 2.87836036, 2.69143211,
#        2.50450386, 2.31757561, 2.13064736, 1.94371911, 1.75679086,
#        1.56986261, 1.38293436, 1.19600611, 1.00907786, 0.82214961])

# %%
plt.plot(x,y, label = 'f(x) = sin(x / 5) * exp(x / 10) + 5 * exp(-x / 2)')
plt.plot(x_pribl,y_pribl, label = ' y = -0.18692825*x + 3.43914511')
plt.title('График функции', fontsize = 18)
plt.ylabel('Y', fontsize = 15)
plt.xlabel('X', fontsize = 15)
plt.legend(loc = 'best')

# %%
x[1],y[1],x[4],y[4],x[10],y[10],x[15],y[15],
# Out:
# (1,
#  3.252216865271419,
#  4,
#  1.7468459495903677,
#  10,
#  2.5054164070002463,
#  15,
#  0.6352214195786656)

# %%
x_l2=[[1,1,1,1],[4**3,4**2,4,1],[10**3,10**2,10,1],[15**3,15**2,15,1]]
y_r2=[[y[1]],[y[4]],[y[10]],[y[15]]]

# %%
f_coef = linalg.solve(x_l2,y_r2)

# %%
f_coef
# Out:
# array([[-0.00823565],
#        [ 0.19333685],
#        [-1.29552587],
#        [ 4.36264154]])

# %%
def func1(x):
    y = 0.32886715*(x**3) -0.88224797*(x**2) + 0.31088868*x + 3.494709   
    return y

# %%
x_pribl1 = np.array([i for i in range(15)])
y_pribl1 = np.array([func1(x_pribl1) for x_pribl1 in range(15)])
y_pribl1
# Out:
# array([  3.494709  ,   3.25221686,   3.21843168,   5.36655636,
#         11.6697938 ,  24.1013469 ,  44.63441856,  75.24221168,
#        117.89792916, 174.5747739 , 247.2459488 , 337.88465676,
#        448.46410068, 580.95748346, 737.338008  ])

# %%
plt.plot(x,y, label = 'f(x) = sin(x / 5) * exp(x / 10) + 5 * exp(-x / 2)')
plt.plot(x_pribl,y_pribl, label = ' y = -0.18692825*x + 3.43914511')
plt.plot(x_pribl1,y_pribl1, label = ' y = 0.32886715*(x^3) -0.88224797*(x^2) + 0.31088868*x + 3.494709')
plt.title('График функции', fontsize = 18)
plt.ylabel('Y', fontsize = 15)
plt.xlabel('X', fontsize = 15)
plt.legend(loc = 'best')

# %%
15**2
# Out:
# 225
